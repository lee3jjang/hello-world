# %% [markdown]
# <a href="https://colab.research.google.com/github/lee3jjang/risk_management/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 이 것은 마크다운 문서입니다.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 100, 100)
y = np.sin(x)
plt.plot(x, y)
