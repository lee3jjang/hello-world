# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.Graph()
G.add_node(1)
G.add_nodes_from([2,3])
nx.draw_shell(G)

# %%
H = nx.path_graph(10)
nx.draw_shell(H)

# %%
G.add_nodes_from(H)
G.add_node(H)
nx.draw_shell(G)

# %%
G.add_edge(1, 2)
nx.draw_shell(G)

# %%
e = (2,3)
G.add_edge(*e)
nx.draw_shell(G)

# %%
G.add_edges_from([(1,2), (1,3)])
nx.draw_shell(G)

# %%
from mayavi import mlab
import numpy as np
import networkx as nx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-37-0a2385f7a7fe> in <module>()
# ----> 1 from mayavi import mlab
#       2 import numpy as np
#       3 import networkx as nx
#
# ModuleNotFoundError: No module named 'mayavi'

# %%
H = nx.cycle_graph(20)
nx.draw_shell(H)

# %%
G = nx.grid_2d_graph(5,5)
nx.draw(G)

# %%
nx.write_edgelist(G, path="grid.edgelist", delimiter=":")
H = nx.read_edgelist(path="grid.edgelist", delimiter=":")

# %%
nx.draw(H)

# %%
G = nx.gnp_random_graph(10, 0.1)
nx.draw(G)

# %%
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)
dmax = max(degree_sequence)
plt.plot(degree_sequence, 'b-', marker='o')
print(degree_sequence)
plt.show()
# Out:
# [3, 2, 2, 1, 1, 1, 1, 1, 0, 0]

# %%
plt.axes([0.45, 0.45, 0.45, 0.45])
plt.axis('off')
plt.show()

# %%
Gcc.degree()
# Out:
# DegreeView({8: 3, 1: 2, 3: 1, 5: 2})

# %%
pos
# Out:
# {8: array([-0.06260962,  0.14045831]),
#  1: array([-0.07400708, -0.71652011]),
#  3: array([-0.44575334,  1.        ]),
#  5: array([ 0.58237004, -0.42393819])}

# %%
Gcc = sorted(nx.connected_component_subgraphs(G), key=len, reverse=True)[0]
pos = nx.spring_layout(Gcc)
plt.axis('off')
nx.draw_networkx_nodes(Gcc, pos, node_size=100)
nx.draw_networkx_edges(Gcc, pos, alpha=0.5)
plt.show()
